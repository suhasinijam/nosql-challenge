# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# !mongoimport --type json -d uk_food -c establishments --drop --jsonArray ./Resources/establishments.json
# Out:
# 2023-12-29T13:22:22.259-0600	connected to: mongodb://localhost/
# 2023-12-29T13:22:22.260-0600	dropping: uk_food.establishments
# 2023-12-29T13:22:23.367-0600	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'autosarus',
#  'classDB',
#  'config',
#  'epa',
#  'fruits_db',
#  'local',
#  'met',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.collection_names()
# Out:
# C:\Users\skvar\AppData\Local\Temp\ipykernel_23004\1966569860.py:2: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   db.collection_names()
# ['establishments']

# %%
# review a document in the establishments collection
db.establishments.find_one()
# Out:
# {'_id': ObjectId('658f1c6ec1356815fc31990c'),
#  'FHRSID': 254250,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000066174',
#  'BusinessName': 'The Pines Calyx',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'AddressLine1': 'The Pines Garden',
#  'AddressLine2': 'Beach Road',
#  'AddressLine3': 'St Margarets Bay',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT15 6DZ',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2021-08-17T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.383298', 'latitude': '51.148133'},
#  'RightToReply': '',
#  'Distance': 4587.362402580997,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/254250'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
restaurant_details = {
    'BusinessName': 'Penang Flavours',
    'BusinessType': 'Restaurant/Cafe/Canteen',
    'RatingValue': 'None'
    
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(restaurant_details)

# %%
# Check that the new restaurant was inserted
results = establishments.find(restaurant_details)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('658f1c7c26c610a472c1d94a'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'RatingValue': 'None'}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
from pprint import pprint

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': {'$in': ['Restaurant/Cafe/Canteen']}}
field = {'BusinessTypeID': 1}
results = list(establishments.find(query, field))
pprint(results)
# Out:
# [{'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31990d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319911')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319912')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319913')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319919')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31991c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31991e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31991f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319921')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319927')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319928')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31992a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31992b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319930')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319932')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31993b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31993e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31993f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319940')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319943')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319944')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319946')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31994b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31994c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31994d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319950')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319953')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319956')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319958')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319959')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31995e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319960')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319964')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319967')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319969')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31996e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31996f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319972')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319978')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31997a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31997c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319982')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319987')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319989')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31998c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31998e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31998f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319992')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319993')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319996')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319997')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319998')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31999e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199ab')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199b1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199b9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199ba')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199c3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199c8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199d6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199d8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199dd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199df')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199e1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199e9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199ec')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199f1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc3199f7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a05')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a06')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a08')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a0e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a0f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a12')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a17')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a1f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a24')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a25')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a2f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a30')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a3f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a40')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a41')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a46')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a49')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a4b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a4c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a50')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a51')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a53')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a55')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a57')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a58')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a59')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a5a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a5e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a60')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a61')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a62')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a63')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a67')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a69')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a75')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a79')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a7a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a7b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a7c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a85')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a86')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a87')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a88')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a8a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a90')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a91')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a94')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a95')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319a9b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319aa5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319aa6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319aab')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ab1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ab2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ab4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ab5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ab8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ac1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ac3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ac4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319aca')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319acc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319acf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ad2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ad6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ad9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319adb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319adf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319aea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319aff')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b00')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b28')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b2f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b30')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b33')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b35')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b38')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b47')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b6a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b6d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b74')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b81')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b84')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b88')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b89')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319b97')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ba3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ba5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ba8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bad')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bb1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bb2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bb7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bb9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bbd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bc0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bc7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bc8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bcc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bd1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319be0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319beb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bf1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bf2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bf6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bf7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319bfd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c05')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c06')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c14')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c1b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c1d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c21')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c23')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c26')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c2a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c37')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c3c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c42')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c45')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c4b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c4c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c51')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c52')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c53')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c55')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c56')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c57')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c59')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c5e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c62')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c65')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c68')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c6a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c6b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c6d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c6f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c72')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c7b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c7d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c7f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c83')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c84')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c86')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c88')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c8b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c90')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c91')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c93')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c94')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c98')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319c99')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ca1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ca7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc319ca9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc
},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a234')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a236')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a239')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a23a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a25e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a260')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a263')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a26b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a26c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a26f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a271')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a272')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a273')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a275')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a27a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a281')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a284')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a286')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a287')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a28b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a28f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a293')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a29e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a29f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2a1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2a4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2a9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2ac')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2b9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2be')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2c0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2c5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2c8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2cc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2cd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2d1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2d6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2d8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2e3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2e5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2e6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2e9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2eb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2ec')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6ec1356815fc31a2f9')},
# ...
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32313e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32313f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323140')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323143')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323145')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32314f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323157')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32315a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32315f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323161')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323164')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323166')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323169')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323175')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323176')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32317b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32317c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32317d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32317e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323181')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323182')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323189')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323190')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323194')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323197')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32319e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ac')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ad')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231af')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231b1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231b2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231b7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ba')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231c9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231d0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231d6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231d7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231d8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231dd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231e1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231eb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231f2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231f8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231fc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231fd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231fe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3231ff')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323204')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323208')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323213')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32321a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32321b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32321d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32321f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323225')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323226')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323227')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32322c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32322f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323233')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32323a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32323b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323241')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323243')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323244')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323246')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323247')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323249')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32324d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323254')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323255')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323257')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323258')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32325a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32325b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32325c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32325d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32325e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323260')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323264')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323269')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32326a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32326b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323272')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32327a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32327c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32327d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323281')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323284')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323285')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323286')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323287')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323288')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323289')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32328b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323290')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323291')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323292')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323294')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323296')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323297')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323298')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32329a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232a0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232a4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232ae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232b7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232bc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232bd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232c0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232c2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232c4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232ca')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232d9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3232df')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323302')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323309')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32330c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323313')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323314')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323315')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323317')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32331a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32331c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32331d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32331e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32331f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323323')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323331')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323335')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323340')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323343')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323346')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32334b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323355')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323357')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32335d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32335e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323361')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323362')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323363')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323368')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32336f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323380')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323383')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32338d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32338e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323394')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323399')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32339d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233a0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233ae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233bd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233be')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233bf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233c1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233c3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233c8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233c9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233cb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233d0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233d6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233d8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233d9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233db')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233dc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233dd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233e2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233e4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233e6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233ed')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233ee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233f0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233f1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233f6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc3233f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323401')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323403')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32340f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323413')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323415')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323416')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323417')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32341a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323427')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323432')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323435')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32343c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323447')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32344f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323451')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc323455')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32345a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32345e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32345f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('658f1c6fc1356815fc32346b')},
#  {'_id': ObjectId('658f1c7c26c610a472c1d94a')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
    {"BusinessName": "Penang Flavours"},
    {"$set": {"BusinessTypeID": 1}}
)

# %%
# Confirm that the new restaurant was updated
query =({"BusinessName": "Penang Flavours"})
establishments.find_one(query)
# Out:
# {'_id': ObjectId('658f1c7c26c610a472c1d94a'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'RatingValue': 'None',
#  'BusinessTypeID': 1}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query ={'LocalAuthorityName': 'Dover'}
count = establishments.count_documents(query)
print(count)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query ={'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
results = establishments.find(query)
for result in results:
    print(result)

# %%
# Check that other documents remain with 'find_one'
results = establishments.find_one(query)
print(results)
# Out:
# None

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set':{'geocode.longitude':{'$toDouble': '$geocode.longitude'}}}, {'$set':{'geocode.latitude':{'$toDouble': '$geocode.latitude'}}}]
)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
results = establishments.find({"RatingValue" : {'$type': "int"}})

# %%
# Check that the coordinates and rating value are now numbers
df_result = pd.DataFrame(results)
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
